# %% [markdown]
# # RFM & Cohort Analysis Notebook
# This notebook reproduces the analysis.

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt

pd.options.display.max_columns = 50

# %%
df = pd.read_excel(r'/mnt/data/Online Retail.xlsx')
df.head()

# %% [markdown]
# Follow the README.md for full reproducible steps and explanations.
